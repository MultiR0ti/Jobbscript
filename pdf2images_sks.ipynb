# %%
#pip install opencv-contrib-python

# %%
import os
import fitz  #pymupdf
from pathlib import Path
import cv2
import numpy as np

# %%
def clip_image(i, name):
    
    img = cv2.imread(i) # Read in the image and convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = 255*(gray < 128).astype(np.uint8) # To invert the text to white
    coords = cv2.findNonZero(gray) # Find all non-zero points (text)
    x, y, w, h = cv2.boundingRect(coords) # Find minimum spanning bounding box
    rect = img[y:y+h, x:x+w] # Crop the image - note we do this on the original image
    print(f'Cropping image {name} x:{x}, y:{y}, w:{w}, h:{h}')
    cv2.imwrite(i, rect) # Save the image

# %%
def pdf2img(p):
    """
    p: path of pdf directory
    
    requires 'clip_image' function
    
    """
    p_out = p + r'\images'
    Path(p_out).mkdir(parents=True, exist_ok=True)  # create the 'images' folder if it doesn't exist
    path = Path(p)
    l_pdfs = [f for f in path.glob('*.pdf')]
    for pdf in l_pdfs:
        print(f'Opening: {pdf}')
        doc = fitz.open(pdf)
        page = doc.loadPage(0)
        print(pdf.stem, page.MediaBox)
        #print(page.MediaBox[3])
        zoom = 2
        zz = fitz.Matrix(zoom, zoom)
        pix = page.getPixmap(matrix = zz)
        f_out = os.path.join(p_out, pdf.stem + '.png')
        #print(f'Extracting: {f_out}')
        pix.writeImage(f_out)
        
        #print(f' image {pdf.stem} x:{x}, y:{y}, w:{w}, h:{h}')
        print(f' rect {page.rect}')
        print(f' CB {page.CropBox}')
        print(f' rect {page.MediaBox}')
        
        try:
            clip_image(f_out, pdf.stem)
        except:
            print(f'failed clip on {f_out}')

# %%
#for example:   

p_in = r'C:\bin\data\GeoTools\PDF2PNG\PDF\220920'  # path to pdf directory
pth = r'C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs'
pdf2img(pth)
# Out:
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA001.pdf
# SA001 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA001 x:104, y:123, w:1398, h:82
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA002_1.pdf
# SA002_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA002_1 x:105, y:110, w:1418, h:640
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA002_2.pdf
# SA002_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA002_2 x:122, y:124, w:1438, h:821
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA003_1.pdf
# SA003_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA003_1 x:109, y:120, w:1443, h:425
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA003_2.pdf
# SA003_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA003_2 x:105, y:110, w:1436, h:147
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA004.pdf
# SA004 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA004 x:124, y:112, w:1383, h:351
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA005_1.pdf
# SA005_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA005_1 x:145, y:133, w:1122, h:923
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA006_1.pdf
# SA006_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA006_1 x:125, y:123, w:1211, h:947
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA006_2.pdf
# SA006_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA006_2 x:117, y:115, w:1424, h:618
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA007_1.pdf
# SA007_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA007_1 x:136, y:110, w:1409, h:517
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA008.pdf
# SA008 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA008 x:121, y:128, w:1425, h:381
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA009_1.pdf
# SA009_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA009_1 x:110, y:113, w:1433, h:891
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA009_2.pdf
# SA009_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA009_2 x:105, y:117, w:1428, h:647
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA011_1.pdf
# SA011_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA011_1 x:122, y:117, w:1423, h:402
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA011_2.pdf
# SA011_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA011_2 x:114, y:136, w:1449, h:237
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA014_1.pdf
# SA014_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA014_1 x:121, y:321, w:1246, h:721
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA015_1.pdf
# SA015_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA015_1 x:117, y:114, w:1421, h:952
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA015_2.pdf
# SA015_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA015_2 x:113, y:119, w:1427, h:610
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA016_1.pdf
# SA016_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA016_1 x:123, y:114, w:1436, h:952
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA016_2.pdf
# SA016_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA016_2 x:112, y:113, w:1432, h:780
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA017_1.pdf
# SA017_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA017_1 x:138, y:119, w:1389, h:898
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA017_2.pdf
# SA017_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA017_2 x:106, y:117, w:1408, h:714
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA018.pdf
# SA018 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA018 x:106, y:113, w:1438, h:134
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA019_1.pdf
# SA019_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA019_1 x:158, y:114, w:1123, h:951
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA019_2.pdf
# SA019_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA019_2 x:168, y:233, w:1364, h:323
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA019_3.pdf
# SA019_3 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA019_3 x:180, y:148, w:1160, h:903
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA021.pdf
# SA021 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA021 x:108, y:122, w:1411, h:113
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA022_1.pdf
# SA022_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA022_1 x:147, y:126, w:1363, h:433
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA022_2.pdf
# SA022_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA022_2 x:136, y:138, w:1380, h:396
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA022_3.pdf
# SA022_3 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA022_3 x:157, y:152, w:1380, h:368
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA023_1.pdf
# SA023_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA023_1 x:191, y:133, w:895, h:932
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA023_2.pdf
# SA023_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA023_2 x:131, y:120, w:1415, h:557
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA024.pdf
# SA024 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA024 x:118, y:132, w:1445, h:264
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA026.pdf
# SA026 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA026 x:164, y:127, w:1020, h:944
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA028_1.pdf
# SA028_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA028_1 x:107, y:115, w:1421, h:846
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA028_2.pdf
# SA028_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA028_2 x:162, y:133, w:1342, h:896
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA031_1.pdf
# SA031_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA031_1 x:160, y:155, w:1067, h:895
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA031_2.pdf
# SA031_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA031_2 x:156, y:111, w:1067, h:944
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA032_1.pdf
# SA032_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA032_1 x:146, y:135, w:1390, h:624
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA032_2.pdf
# SA032_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA032_2 x:132, y:128, w:1388, h:544
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA033_1.pdf
# SA033_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA033_1 x:224, y:143, w:1305, h:792
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA033_2.pdf
# SA033_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA033_2 x:157, y:137, w:1379, h:911
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA037_1.pdf
# SA037_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA037_1 x:119, y:112, w:1407, h:956
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA037_2.pdf
# SA037_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA037_2 x:138, y:113, w:1408, h:773
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA038_1.pdf
# SA038_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA038_1 x:116, y:117, w:1289, h:960
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA038_2.pdf
# SA038_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA038_2 x:107, y:112, w:1436, h:965
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA044_1.pdf
# SA044_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA044_1 x:147, y:133, w:1379, h:796
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA044_2.pdf
# SA044_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA044_2 x:145, y:129, w:1425, h:587
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA044_3.pdf
# SA044_3 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA044_3 x:180, y:152, w:1205, h:922
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA045_1.pdf
# SA045_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA045_1 x:173, y:128, w:1333, h:846
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA045_2.pdf
# SA045_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA045_2 x:132, y:159, w:1404, h:611
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA045_3.pdf
# SA045_3 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA045_3 x:151, y:136, w:1370, h:425
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA046_1.pdf
# SA046_1 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA046_1 x:186, y:161, w:883, h:903
# Opening: C:\bin\data\GeoTools\EQN\OneDrive_1_9-23-2022\SA\pdfs\SA046_2.pdf
# SA046_2 Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.9199829101562, 595.3200073242188)
#  CB Rect(0.0, 0.0, 841.92, 595.32)
#  rect Rect(0.0, 0.0, 841.92, 595.32)
# Cropping image SA046_2 x:151, y:121, w:1386, h:348
