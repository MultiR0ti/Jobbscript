# %%
from snd_df import SndfilTilML
from tot_df import TotfilTilML

snddf = SndfilTilML.clean_snd_df('SS-12026.SND') 
totdf = TotfilTilML.clean_tot_df('SS-12026 20180305 1255.TOT')

# %%
snddf.iloc[0:60]
# Out:
#     Dybde  Trykk Bortid Spyle S(spyling?) R(rotasjon?) Y(slag?)
# 0   0.025    669    802    60           0            0        1
# 1   0.050   4987    778     7           1            0        1
# 2   0.075   7818    787    14           1            1        1
# 3   0.100   3206    756   235           1            1        1
# 4   0.125   7257    767    13           1            1        1
# 5   0.150   7501    863    14           1            1        1
# 6   0.175   6903   1038    16           1            1        1
# 7   0.200   1132   1053    29           1            1        1
# 8   0.225   2206   1037    17           1            1        1
# 9   0.250    778   1006    39           1            1        1
# 10  0.275   4597    839     8           1            1        1
# 11  0.300   5268    824    10           1            1        1
# 12  0.325   5122    813    10           1            1        1
# 13  0.350   4548    797     8           1            1        1
# ...

# %%
totdf.iloc[0:60]
# Out:
#    Dybde(D) Matekraft(A) Bortid(B)  ...      J             T  Tolkning
# 1     0.025        0.405     4.279  ...  0.000  Tele/Matjord  Tolkning
# 2     0.050        1.320     4.754  ...  0.000           NaN  Tolkning
# 3     0.075        1.247    20.966  ...  0.000           NaN  Tolkning
# 4     0.100        1.393    19.844  ...  0.000           NaN  Tolkning
# 5     0.125        1.015     9.372  ...  0.000           NaN  Tolkning
# 6     0.150        1.503    19.590  ...  0.000           NaN  Tolkning
# 7     0.175        0.783     9.256  ...  0.000           NaN  Tolkning
# 8     0.200        3.028    34.314  ...  0.000           NaN  Tolkning
# 9     0.225        1.796    19.231  ...  0.000           NaN  Tolkning
# 10    0.250        1.479    17.809  ...  0.000           NaN  Tolkning
# 11    0.275        1.137    22.074  ...  0.000           NaN  Tolkning
# 12    0.300        1.198    23.412  ...  0.000           NaN  Tolkning
# ...
