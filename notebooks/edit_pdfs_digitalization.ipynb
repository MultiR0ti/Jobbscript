# %%
from pathlib import Path
import os
import io
import cv2
import fitz
from PIL import Image, ImageDraw, ImageFont
from PyPDF2 import PdfMerger, PdfWriter, PdfReader
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter, A4
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
import pytesseract
pytesseract.pytesseract.tesseract_cmd = (
        r"C:\Users\jdr\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"
    )

# %%
def write_drawing_num(pdfs_path):

    path = Path(pdfs_path)
    list_pdfs = [f for f in path.glob('*.pdf')]
    list_pdfs.sort()

    for index, pdf in enumerate(list_pdfs):
        pdf_path = os.path.join(pdfs_path, pdf.stem + '.pdf')
        pdfmetrics.registerFont(TTFont('isocpeur', 'isocpeur.ttf'))
        packet = io.BytesIO()
        can = canvas.Canvas(packet, pagesize=A4)
        can.setFont('isocpeur', 11)
        can.rotate(270)
        pdf_path = os.path.join(pdfs_path, pdf.stem + '.pdf')
        pdf_name = pdf_path.split("\\")[-1]
        drawing_number = '010'
        text = "RIG-TEG-"+ pdf_name.replace('.pdf', '') + '-' + drawing_number
        can.drawString(-150, 25, text, direction='ltr')
        can.save()

        #move to the beginning of the StringIO buffer
        packet.seek(0)

        # create a new PDF with Reportlab
        new_pdf = PdfReader(packet)
        # read your existing PDF
        existing_pdf = PdfReader(open(pdf, "rb"))
        output = PdfWriter()
        # add the "watermark" (which is the new pdf) on the existing page
        page = existing_pdf.pages[0]
        page.merge_page(new_pdf.pages[0])
        output.add_page(page)
        # finally, write "output" to a real file
        output_stream = open(pdf_path, "wb")
        output.write(output_stream)
        output_stream.close()

# %%
def find_bp_names_and_rename_imgs_and_pdfs(img_folder: str):
    '''Uses OCR to find the name of the boring to rename the image with that name.
    With the font used in AutoCAD 7 is interpreted as / so logic is made to correct the name.
    Made for borings named like: SB-1000.
    If a boring is split in two pages, the second page will be named "SB-X" plus the index of the file. 
    '''
    path = Path(img_folder)
    list_pngs = [f for f in path.glob('*.png')]
    bp_names = []

    for i, picture in enumerate(list_pngs):
        img_path = os.path.join(img_folder, picture.stem + '.png')
        pdf_path = os.path.join(img_folder, picture.stem + '.pdf')
        text = str(((pytesseract.image_to_string(Image.open(img_path)))))
        
        text.strip()
        print(text)
        bp_name = text.partition('\n')[0].replace(' ', '')
        fix_bp_name = bp_name.replace('/', '7')
        #print(fix_bp_name)
        if 'SB' in fix_bp_name:
            file_name = fix_bp_name[:-1] if len(fix_bp_name) > 7 else fix_bp_name
            print('Justert til: ', file_name)
        else:
            file_name = 'SB-X' + str(i)
        bp_pic_path = img_folder + '\\' + file_name + '.png'
        bp_pdf_path = img_folder + '\\' + file_name + '.pdf'
        # os.rename(img_path, bp_pic_path)
        # os.rename(pdf_path, bp_pdf_path)

# %%
def pdf2img(pdf_path: str):
    """
    pdf_path: path of a pdf file.
    
    Creates images from pages of a pdf file.
    """
    #img_path = pdf_path + r'\images'
    #Path(img_path).mkdir(parents=True, exist_ok=True)  # create the 'images' folder if it doesn't exist
    img_path = os.path.dirname(pdf_path) + r'\images\\'
    Path(img_path).mkdir(parents=True, exist_ok=True) 
    doc = fitz.open(pdf_path)
    for index, page in enumerate(doc.pages()):
        zoom = 3
        zz = fitz.Matrix(zoom, zoom)
        pix = page.get_pixmap(matrix=zz)
        pix.save(img_path + str(index) + r'.png')

# %%
def pdf_splitter(path):
    fname = os.path.splitext(os.path.basename(path))[0]
    new_path = '\\'.join(path.split('\\')[:-1]) + '\\images'
    pdf = PdfReader(path)
    for page in range(len(pdf.pages)):
        pdf_writer = PdfWriter()
        pdf_writer.add_page(pdf.pages[page])
        output_filename = '{}\\{}.pdf'.format(new_path, page)
        with open(output_filename, 'wb') as out:
            pdf_writer.write(out)

# %%
# Open the image file
def convert_images_to_pdf(img_folder: str, pdf_filename: str):
    """Converts pngs to pdf files.
    Input: image folder, and name of the resulting pdf.¨
    PDF will be named SB-XXXX_pdf_filname.pdf
    """
    path = Path(img_folder)
    list_pngs = [f for f in path.glob('*.png')]

    for picture in list_pngs:
        img_path = os.path.join(img_folder, picture.stem + '.png')
        image = Image.open(img_path)
        # Save the image as a PDF file
        image.save(img_folder + '\\' + picture.stem + '_' + pdf_filename, "PDF")

# %%
def merge_pdfs(pdf_folder: str):
    """Merges all pdfs in a folder.
    Input: directory of pdf files to merge.
    Resulting pdf is named Samlet.pdf
    """ 
    path = Path(pdf_folder)
    list_pdfs = [f for f in path.glob('*.pdf')]
    
    merger = PdfMerger()
    
    for pdf in list_pdfs:
        merger.append(open(pdf, 'rb'))
    
    with open(pdf_folder + "\\Samlet.pdf", "wb") as fout:
        merger.write(fout)

# %%
img_folder = r'\\nsv2-nasuni-02\fredrikstad\Prosjekt\O10245\10245026-01\10245026-01-03_ARBEIDSOMRAADE\21_fagomraade\11_Geoteknikk\10245026-10-GEOSUITE\01121-01 Borregaard Kokeri skråning\AUTOGRAF.RIT\images'
pdf_file = r'\\nsv2-nasuni-02\fredrikstad\Prosjekt\O10245\10245026-01\10245026-01-03_ARBEIDSOMRAADE\21_fagomraade\11_Geoteknikk\10245026-10-GEOSUITE\01121-01 Borregaard Kokeri skråning\AUTOGRAF.RIT\Samlet.pdf'
samlet = r'\\nsv2-nasuni-02\fredrikstad\Prosjekt\O10245\10245026-01\10245026-01-03_ARBEIDSOMRAADE\21_fagomraade\11_Geoteknikk\10245026-10-GEOSUITE\01121-01 Borregaard Kokeri skråning\AUTOGRAF.RIT'

#pdf2img(pdf_file)
#pdf_splitter(pdf_file)
find_bp_names_and_rename_imgs_and_pdfs(img_folder=img_folder)

# NB!!: Run the following functions AFTER controlling the PDF file names = boring name!
#write_drawing_num(pdfs_path=img_folder)
#merge_pdfs(samlet)
# Out:
# io Nae
# 500 400 300 200 100
# 0 12 3 4
# Bortid s/m
# Spyletrykk MPa
#
# 5 10 20 30 KN
# MATEKRAFT = STOPP 21.4 m
#
# Oppdragsnr. Profilnr./Bp.nr Hoyde
# 01121 BORPUNKT NA: 1 + 28.49
# 20011029 4: 200
# NVK Terraplan AS aa Cee
# Oppdragsnavn 1 ( 4) -O7
# Fil
#
# Borregaard Ind.Ltd.
#
#
# a 10 20 30 KN
# MATEKRAFT STOPP 17.3 m
#
# 500 400 300 200 100
# 0 12 3 4
# Bortid s/m
#
# Spyletrykk MPa
#
# QOppdragsnr. Profilnr./Bp.nar Hayde
# 9 1: 200
# NVK Terraplan AS ——
# Borregaard Ind.Ltd.
#
#
#
# 5
#
# =
# 500 400 300 200 100
#
# 01244 =) 5 10 20 30 kN
# De MATEKRAFT  STOPP 24.525 m
# Bortid s/m aa
#
# Spyletrykk MPa
#
# Antatt kratell ved
# Ay bce 20.3 m
#
# Oppdragsnr. Profilne./Bp.nr Hayde
# 20011029 4: 200
# NVK Terraplan AS ea
# Borregaard Ind.Ltd.
#
#
# 500 400 300 200 100 20 30 kN
# 0 423 4 MATEKRAFT STOPP 12.4 m
# Bortid s/m
#
# Spyletrykk MPa
#
# Oppdragsnr. Profilnor./Bp.nr Hoyde
# 20011024 4: 200
# NVK Terraplan AS = CREE
#
# Infrastruktur Fornebu 200’ soarcoos tor”
#
#
# ey
# “SS
# { j &
# 500 400 300 200 100
# 04123 4
# Bortid s/m
# Spyletrykk MPa
#
# Fo
# i= C7
# 5 10 20 30 KN
# MATEKRAFT STOPP 8.9 m
#
# Oppdragsnr. Profilnr./Bp.nr Heyde
# 129.2
# Firmanavn Pr Sootto24| 1 200
# 2 1: 200
# NVK Terraplan AS ee
# Oppdragsnavn ~ OF
# Borregaard Ind.Ltd.  gonneoo7. TOT”
#
# <
#
# s|
#
# 3
#
# | Zt
#
# 500 400 300 200 100
#
# 0123 4
# Bortid s/m
#
# Spyletrykk MPa
#
# 5 20 30 KN
# MATEKRAFT = STOPP 12.8 m
#
# Oppdragsnr. Profilnr./B8p.nr Heyde
# NVK Terraplan AS a
# Oppdragsnavn 1 (4)
# Borregaard Ind.Ltd.
#
#
# 10 20 30 KN
# MATEKRAFT STOP 6.325.
#
# 500 400 300 200 100
# 0 123 4
# Bortid s/m
# Spyletrykk MPa
#
# Oppdragsnr. Profilnr./Bp.nr Heyde
# BORPUNKT NR: 9 + 21.84
# 20011024 4: 200
# NVK Terraplan AS _ =—
# Oppdragsnavn 1 ( 4) -01
#
# Borregaard Ind.Ltd.  noAREOOg.TOT *
#
#
# P| |
#
# |
# |
#
# |
# | |
# t |
#
# ify i
# LE |
#
# 500 400 300 200 100 © 10 20 30 KN
# 04234 2 MATEKRAFT STOPP 9.3
# oO
# Bortid s/m =<
# own
#
# Spyletrykk MPa
#
# Oppdragsnr. Profilnr./Bp.nr Hoayde
# 01102 : 200
# NVK Terraplan AS SS
# Oppdragsnavn ~l 0
# Borregaard Ind.Ltd.
#
#
# ee BM NS 2
# 500 400 300 200 100
# 01243 4
# Bortid s/m
# Spyletrykk MPa
#
# MATEKRAFT = STOPP 7.7 m
#
# Oppdragsnr. Profilnr./Bp.nr Hayde
# NVK Terraplan AS ae
# Borregaard Ind.Ltd. me aco i Or:
#
#
# 5 10 20 30 kN
# MATEKRAFT = STOPP 20.35 m
#
# 500 400 300 200 100
# 0423 4
# Bortid s/m
#
# Spyletrykk MPa
#
# Oppdragsnr. Profilnr./Bp.nr Hayde
# 4: 200
# NVK Terraplan AS eo
# Borregaard Ind.Ltd.
#
#
# et |
# 500 400 300 200 100
# 04123 4
# Bortid s/m
# Spyletrykk MPa
#
# 5 10 20 30 kN
# MATEKRAFT  STOPP 24.9 m
#
# Oppdragsnr. Profilnr./Bp.nr Hayde
# 20011017 4: 200
# NVK Terraplan AS = SRE
# Borregaard Ind.Ltd.
#
#
# 500 400 300 200 100 5 10 20 30 KN
#
# 01234 2 MATEKRAFT  STOPP. 27.9 m
# Bortid s/m =<
# nw
#
# Spyletrykk MPa
#
# Stangbruda. Antatt frellniv a”
# ved dybde ~ 235 m
#
# Oppdragsnr. Profilnr./Bp.nr Hayde
# NVK Terraplan AS eee
# Oppdragsnavn HlY
# Borregaard Ind.Ltd.
#
#
# 18
#
# D + 35.96
#
# <
#
# 500 400 300 200 100
#
# = 5 10 20 30 KN
# 01234 4 MATEKRAF T STOPP 28.225 m
# ao
# Bortid s/m a5
# aw
#
# Spyletrykk MPa
#
# Oppdragsnr. Profilnr./Bp.nr Hoyde
# 011214 BORPUNKT NA: 18 + 35.96
# Firmanayn Dato
# 20011018 1: 200
# NVK Terraplan AS nas eat ae
# Oppdragsnavn 1 (4) = [S$
#
# Borregaard Ind.Ltd.
#
#
# 500 400 300 200 100
# 0 4 243 4
#
# Bortid s/m
#
# Spyletrykk MPa
#
# Stung brudd for frell
# ble eA
#
# 5
# MATEKRAFT STOPP 13.275 m
#
# Oppdragsnr. Profilnr./Bp.nr Hayde
# 200
# NVK renpaplan AS a ie 7
# Borregaard Ind.Ltd.
#
#
# 20
#
# DD + 35.31
#
# 30 kN
# MATEKRAFT STOPP 31.9 m
#
# 500 400 300 200 100
# 0 423 4
#
# Bortid s/m
#
# Spyletrykk MPa
#
# SPYLING
# SLAG
#
# Oppdragsnr. Profilnr./Bp.nr Hoyde
# Firmanavn Dato
# : 200
# NVK Terraplan AS —ee
# Oppdragsnayn 1 (1) ~|>
# Borregaard Ind.Ltd. ™ BORREO20.TOT *
#
#
# at
# D + 34,72
#
# 1
#
# =
#
# eS
#
# 500 400 300 200 100 4 10 20 30 KN
#
# 01234 2 WATEKRAFT © STOPP 25.3 m
# Bortid s/m =<
# ow
#
# Spyletrykk MPa
#
# Oppdragsnr. Profilnr./Bp.nr Hayde
# 01124 BORPUNKT NA: 214 + 34.72
# Firmanavn Psoott01a| 1.200
# 20011018 4: 200
# NVK Terraplan AS -— =—
# Oppdragsnavn ~1¢
#
# Borregaard Ind.Ltd.
#
#
# |
# i aT YA
#
# 500 400 300 200 100
#
# |
# 20
#
# 30 kN
#
# 5 10
# 01243 4 2 MATEKRAFT STOPP 22.825 m
# HO
# Bortid s/m Ee
# ou
#
# Spyletrykk MPa
#
# Oppdragsnr. Profilnr./Bp.or Hayde
# BORPUNKT N29 + 34.27
# 20011019 4: 200
# NVK Terraplan AS aa Oe
# il
#
# Borregaard Ind.Ltd.

# %%
def rename_pdf(img_folder: str):
    """Only for long borings"""
    path = Path(img_folder)
    list_pdfs = [f for f in path.glob('*.pdf')]

    for i, pdf in enumerate(list_pdfs):
        pdf_path = os.path.join(img_folder, pdf.stem + '.pdf')
        bp_pdf_path = img_folder + '\\' + pdf.stem + 'I.pdf'
        os.rename(pdf_path, bp_pdf_path)

# %%
img_folder = r'C:\Users\jdr\OneDrive - Multiconsult\Skrivebord\Totsonderinger\Lange\images'
#rename_pdf(img_folder)
